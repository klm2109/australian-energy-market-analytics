# %%
# Import necessary modules
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Read the dataset
df = pd.read_csv("../data/raw/PRICE_AND_DEMAND_202608_NSW1.csv")

# Inspect the data 
df.head()
df.shape
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7776 entries, 0 to 7775
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   REGION          7776 non-null   str
#  1   SETTLEMENTDATE  7776 non-null   str
#  2   TOTALDEMAND     7776 non-null   float64
#  3   RRP             7776 non-null   float64
#  4   PERIODTYPE      7776 non-null   str
# dtypes: float64(2), str(3)
# memory usage: 516.5 KB

# %%
# Convert timestamp 
df["SETTLEMENTDATE"] = pd.to_datetime(df["SETTLEMENTDATE"])

df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7776 entries, 0 to 7775
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   REGION          7776 non-null   str
#  1   SETTLEMENTDATE  7776 non-null   datetime64[us]
#  2   TOTALDEMAND     7776 non-null   float64
#  3   RRP             7776 non-null   float64
#  4   PERIODTYPE      7776 non-null   str
# dtypes: datetime64[us](1), float64(2), str(2)
# memory usage: 372.2 KB

# %%
# Check data quality 
df.isnull().sum()
df.duplicated().sum()
df.describe()
# Out:
#             SETTLEMENTDATE   TOTALDEMAND          RRP
# count                 7776   7776.000000  7776.000000
# mean   2026-08-14 12:02:30   8210.862065    77.059875
# min    2026-08-01 00:05:00   4628.030000   -18.510000
# 25%    2026-08-07 18:03:45   7297.312500    57.390000
# 50%    2026-08-14 12:02:30   8129.005000    73.535000
# 75%    2026-08-21 06:01:15   9112.190000    97.630000
# max    2026-08-28 00:00:00  11651.750000   311.910000
# std                    NaN   1295.783303    36.904946
